# %%
import matplotlib.pyplot as plt

from tagcloud import (
    TagCloud,
    DescendingFrequencyTable,
    FrequencyData
)
from tagcloud.backends.backend_mpl import CanvasMPL

wc = TagCloud(canvas_backend=CanvasMPL)

c = wc.draw(
    frequency_table=DescendingFrequencyTable([
        FrequencyData('test', 1),
        FrequencyData('this', 10),
        FrequencyData('more', 5),
        FrequencyData('stuff', 5),
        FrequencyData('yeehaw', 5),
        FrequencyData('uwu', 5),
    ]),
    text_props=dict(
        size_max=200,
        rotation_range=(0, 0),
        rotation_step=90,
        rotation_prob=.5
    )
)

plt.imshow(c.data_rgba)
# Out:
# text 80 171.0
# text TextSpec(content='this', size=200, rotation=0, position=Coordinate(x=39, y=80)) (80.0, 113.0, 506.875, 270.0)
# text 6 1.0
# text TextSpec(content='more', size=127.0, rotation=0, position=Coordinate(x=308, y=6)) (6.0, -36.0, 456.75, 171.0)
# text 416 342.0
# text TextSpec(content='stuff', size=71.0, rotation=0, position=Coordinate(x=41, y=416)) (416.0, 321.0, 222.125, 97.0)
# text 31 386.0
# text TextSpec(content='yeehaw', size=70.0, rotation=0, position=Coordinate(x=1, y=31)) (31.0, 366.0, 377.75, 93.0)
# text 448 78.0
# text TextSpec(content='uwu', size=66.0, rotation=0, position=Coordinate(x=312, y=448)) (448.0, 59.0, 191.25, 90.0)
# text 476 1.0
# text TextSpec(content='test', size=57.0, rotation=0, position=Coordinate(x=403, y=476)) (476.0, -15.0, 152.0, 76.0)
